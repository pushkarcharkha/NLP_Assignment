# %%
import nltk
from nltk.corpus import wordnet as wn

# %%
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\pushk\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\pushk\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
word = "light"
synsets = wn.synsets(word)
print("Word:", word)
# Out:
# Word: light

# %%
# -------------------
# 1. Synonyms (same meaning)
# -------------------
synonyms = set()
for syn in synsets:
    for lemma in syn.lemmas():
        synonyms.add(lemma.name())

print("Synonyms:", synonyms)
# Out:
# Synonyms: {'faint', 'wakeful', 'lite', 'twinkle', 'scant', 'dismount', 'illume', 'easy', 'luminosity', 'light_source', 'get_down', 'light_up', 'light-headed', 'short', 'unaccented', 'lighter', 'perch', 'Christ_Within', 'unclouded', 'spark', 'brightness', 'Light', 'lightheaded', 'promiscuous', 'idle', 'luminance', 'low-cal', 'loose', 'light-colored', 'fall', 'calorie-free', 'illumine', 'clean', 'clear', 'tripping', 'fire_up', 'light', 'visible_light', 'sluttish', 'lightness', 'Inner_Light', 'visible_radiation', 'luminousness', 'Light_Within', 'unhorse', 'ignitor', 'abstemious', 'ignite', 'swooning', 'wanton', 'weak', 'lightsome', 'brightness_level', 'illumination', 'alight', 'lighting', 'illuminate', 'lightly', 'igniter', 'sparkle', 'get_off'}

# %%
# -------------------
# 2. Antonyms (opposite meaning)
# -------------------
antonyms = set()
for syn in synsets:
    for lemma in syn.lemmas():
        if lemma.antonyms():
            antonyms.add(lemma.antonyms()[0].name())

print("Antonyms:", antonyms)
# Out:
# Antonyms: {'dark', 'heavy', 'extinguish'}

# %%
# -------------------
# 3. Hypernyms (general meaning)
# -------------------
hypernyms = set()
for syn in synsets:
    for hyper in syn.hypernyms():
        for lemma in hyper.lemmas():
            hypernyms.add(lemma.name())

print("Hypernyms:", hypernyms)
# Out:
# Hypernyms: {'land', 'set_down', 'brainstorm', 'descend', 'go_down', 'device', 'view', 'general_knowledge', 'aspect', 'face', 'lighten', 'look', 'perspective', 'morals', 'lighten_up', 'public_knowledge', 'scene', 'ethical_motive', 'fall', 'morality', 'insight', 'visual_signal', 'actinic_radiation', 'physical_property', 'brainwave', 'verve', 'devolve', 'light', 'actinic_ray', 'combust', 'come_down', 'return', 'condition', 'friend', 'visual_property', 'ignite', 'burn', 'facial_expression', 'status', 'illumination', 'ethics', 'position', 'vitality', 'source_of_illumination', 'pass', 'expression'}

# %%
# --------------------
# 4. Hyponyms (specific meaning)
# --------------------
hyponyms = set()
for syn in synsets:
    for hypo in syn.hyponyms():
        for lemma in hypo.lemmas():
            hyponyms.add(lemma.name())

print("\nHyponyms:", hyponyms)
# Out:
# Hyponyms: {'jacklight', 'torch', 'flasher', 'enkindle', 'gaslight', 'headlamp', 'candlelight', 'panel_light', 'riding_light', 'sconce', 'riding_lamp', "will-o'-the-wisp", 'illuminance', 'priming', 'beam', 'fusee', 'lucifer', 'strip_lighting', 'friction_match', 'halo', 'flood_lamp', 'shooting_star', 'highlight', 'irradiation', 'match', 'twilight', 'shaft', 'sun', 'fairy_light', 'light_beam', 'fuze', "friar's_lantern", 'meteor', 'inflame', 'beam_of_light', 'streamer', 'kindle', 'counterglow', 'corona', 'gegenschein', 'highlighting', 'blinker', 'flood', 'searchlight', 'moonlight', 'light', 'glow', 'radiance', 'aura', 'scintillation', 'glowing', 'reignite', 'running_light', 'flare_up', 'photoflood', 'navigation_light', 'moonshine', 'light_up', 'pocket_lighter', 'brightness', 'nimbus', 'anchor_light', 'incandescence', 'ray_of_light', 'cigar_lighter', 'conflagrate', 'ignis_fatuus', 'half-light', 'sunniness', 'aureole', 'fire_up', "jack-o'-lantern", 'illumination', 'night-light', 'traffic_signal', 'shaft_of_light', 'glory', 'fuse', 'starlight', 'sunlight', 'torchlight', 'cigarette_lighter', 'fluorescence', 'firelight', 'ray', 'stoplight', 'daylight', 'floodlight', 'luminescence', 'candle_flame', 'houselights', 'traffic_light', 'Moon', 'room_light', 'gloriole', 'fuzee', 'headlight', 'primer', 'spotlight', 'theater_light', 'lamplight', 'sunshine', 'sidelight'}
